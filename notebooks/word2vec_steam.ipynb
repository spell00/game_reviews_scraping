# %%
import os

# The notebook is a subfolder, must go back to parent folder
# Note that if if cell is executed twice, the remaining cells
# will fail because the current working directory will be wrong
os.chdir("..")

# %%
from src.vectorize import EmbeddingsModel
from tqdm import tqdm
import numpy as np
from pattern.text.en import parse
import pandas as pd
import jsbeautifier
from src.scrape import *

# %% [markdown]
# # Part I: Identify a few games
#
# With word embeddings, a lot of games can be found automatically.
# However, before doing so, we need to identify some games first (we will assume we know none of the games that are being reviewed).

# %%
scrape_games = True
if scrape_games:
    look_for_words()
    unique_words()
    words_abbreviation()
    count_words()
# Out:
# Finding games...

# %% [markdown]
# # Part II: Create a dataframe
#
# All the relevant information within the json file will be organised into a well-organised pandas DataFrame to make all subsequent steps easier.
#
# The Dataframe will be saved as a csv file which can be reloaded later to accelerate the process.

# %% [markdown]
# The following step needs only to be done once per corpus

# %%
make_csv = False
if make_csv:
    build_dataframe(get_more_infos=True)
    normalize_csv(spell_check=True)
    get_word2vec_vocab()
    normalize_csv_for_word2vec()

# %% [markdown]
# ### Find The most mentionned games among the ones that were found

# %%
scraped_games = pd.read_table("extracted/lists/game_lines.csv", sep='[')
scraped_games.columns = ["Game", "mentions"]
games = np.array(scraped_games["Game"])
games = np.array([g.strip(",") for g in games])
scraped_games["Game"] = games

new_df = pd.DataFrame(index=games, data=np.array([None for _ in games]).reshape(-1, 1), columns=["n_mentions"])
for i, key in enumerate(range(len(scraped_games["Game"]))):
    new_df["n_mentions"][i] = len(scraped_games["mentions"][i].split(","))
# There is some noise: The Game, Well There, The Launcher et Now 
# Insurgency Really is about a game called Insurgency

new_df = new_df.sort_values(by=['n_mentions'], ascending=False)
new_df
# Out:
#                                 n_mentions
# Team Fortress 2                        251
# Nuclear Throne                         232
# Dont Starve                             86
# Dota 2                                  79
# Insurgency Really                       65
# Portal                                  51
# Sonic Generations                       49
# Counter Strike Global Offensive         43
# Well There                              36
# The Culling                             27
# Garrys Mod                              26
# The Community                           24
# Starbound                               22
# Sanctum 2                               20
# Tf2                                     19
# Half Life 2                             17
# Undertale                               16
# Cs:go                                   11
# Loadout                                 10
# Evolve                                   8
# Dishonored                               8
# Super Meat Boy                           7
# Csgo                                     5
# Nether                                   5
# Boderlands 2                             4
# The Elder Scrolls V: Skyrim              4
# Metro 2033                               3
# Besiege                                  3
# Airmech                                  3
# Zombie Army Trilogy                      2
# Men Of War                               1
# Murdered: Soul Suspect                   1
# Red Faction Guerrilla                    1
# Castle Miner Z                           1
# Zombie Army Trlogy                       1
# The Stomping Land                        1

# %% [markdown]
# # Part III: Identify word embeddings (word2vec)

# %%
my_model = EmbeddingsModel()
train = False
direc = "saved_models/gensim_model"
model_name = "pretrained_GoogleNews-vectors-negative300"
checkpoint_fname = "steam_australia_norm_w2v"
chechpoint_path = "{}/{}".format(direc, model_name)
if train:
    my_model.train(checkpoint_fname + ".csv", checkpoint=chechpoint_path)
    my_model.save_model(checkpoint)
my_model.load_model("{}/{}.model".format(chechpoint_path, checkpoint_fname))
# Out:
# 2019-12-18 04:55:31,473 : INFO : loading Word2Vec object from saved_models/gensim_model/pretrained_GoogleNews-vectors-negative300/steam_australia_norm_w2v.model
# 2019-12-18 04:55:42,518 : INFO : loading wv recursively from saved_models/gensim_model/pretrained_GoogleNews-vectors-negative300/steam_australia_norm_w2v.model.wv.* with mmap=None
# 2019-12-18 04:55:42,519 : INFO : loading vectors from saved_models/gensim_model/pretrained_GoogleNews-vectors-negative300/steam_australia_norm_w2v.model.wv.vectors.npy with mmap=None
# 2019-12-18 04:55:49,171 : INFO : setting ignored attribute vectors_norm to None
# 2019-12-18 04:55:49,185 : INFO : loading vocabulary recursively from saved_models/gensim_model/pretrained_GoogleNews-vectors-negative300/steam_australia_norm_w2v.model.vocabulary.* with mmap=None
# 2019-12-18 04:55:49,189 : INFO : loading trainables recursively from saved_models/gensim_model/pretrained_GoogleNews-vectors-negative300/steam_australia_norm_w2v.model.trainables.* with mmap=None
# 2019-12-18 04:55:49,190 : INFO : loading syn1neg from saved_models/gensim_model/pretrained_GoogleNews-vectors-negative300/steam_australia_norm_w2v.model.trainables.syn1neg.npy with mmap=None
# 2019-12-18 04:55:58,652 : INFO : setting ignored attribute cum_table to None
# 2019-12-18 04:55:58,729 : INFO : loaded saved_models/gensim_model/pretrained_GoogleNews-vectors-negative300/steam_australia_norm_w2v.model

# %%
tops_games = {
    'Borderlands': None,
    'borderlands': None,
    'FFIV': None,
    'Team_Fortress_2': None,
    'Dont_Starve': None,
}
for top in tops_games:
    tops_games[top] = my_model.model.most_similar(top, topn=100)
    tops_games[top] = pd.DataFrame(tops_games[top], columns=["word", "similarity"])
# Out:
# 2019-12-18 04:56:08,791 : INFO : precomputing L2-norms of word weight vectors
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-ef857d25f558> in <module>
#       7 }
#       8 for top in tops_games:
# ----> 9     tops_games[top] = my_model.model.most_similar(top, topn=100)
#      10     tops_games[top] = pd.DataFrame(tops_games[top], columns=["word", "similarity"])
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/gensim/utils.py in new_func1(*args, **kwargs)
#    1445                     stacklevel=2
#    1446                 )
# -> 1447                 return func(*args, **kwargs)
#    1448
#    1449             return new_func1
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/gensim/models/base_any2vec.py in most_similar(self, positive, negative, topn, restrict_vocab, indexer)
#    1395
#    1396         """
# -> 1397         return self.wv.most_similar(positive, negative, topn, restrict_vocab, indexer)
#    1398
#    1399     @deprecated("Method will be removed in 4.0.0, use self.wv.wmdistance() instead")
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/gensim/models/keyedvectors.py in most_similar(self, positive, negative, topn, restrict_vocab, indexer)
#     551                 mean.append(weight * word)
#     552             else:
# --> 553                 mean.append(weight * self.word_vec(word, use_norm=True))
#     554                 if word in self.vocab:
#     555                     all_words.add(self.vocab[word].index)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/gensim/models/keyedvectors.py in word_vec(self, word, use_norm)
#     466             return result
#     467         else:
# --> 468             raise KeyError("word '%s' not in vocabulary" % word)
#     469
#     470     def get_vector(self, word):
#
# KeyError: "word 'Team_Fortress_2' not in vocabulary"

# %%
tops_games['Dont_Starve'][:20]

# %%
tops_games['Borderlands'][:20]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-dd87d57669b2> in <module>
# ----> 1 tops_games['Team_Fortress'][:20]
#
# KeyError: 'Team_Fortress'

# %%
my_model.model.most_similar("dungeon_crawl", topn=100)
# Out:
# [('cartsale', 0.5178236365318298),
#  ('varipapa', 0.5139137506484985),
#  ('melmore', 0.486359566450119),
#  ('pinnacle', 0.47330403327941895),
#  ('stunningly', 0.4599151313304901),
#  ('graceful', 0.45636147260665894),
#  ('promoval', 0.45410484075546265),
#  ('elysha', 0.45378682017326355),
#  ('pessimal', 0.45335930585861206),
#  ('josephine', 0.4487398564815521),
#  ('subgenre', 0.4467489421367645),
#  ('ascham', 0.4453892707824707),
#  ('basov', 0.44531571865081787),
#  ('exquisite', 0.4417992830276489),
#  ('haunting', 0.4398704767227173),
#  ('ageing', 0.4387240707874298),
#  ('backdrops', 0.43105560541152954),
#  ('chaksi', 0.42683690786361694),
#  ('Zion_Canyon', 0.4229912757873535),
#  ('animalistic', 0.4164268374443054),
#  ('balneum', 0.41634970903396606),
#  ('firefall', 0.4122198820114136),
#  ('picturesque_landscapes', 0.411774218082428),
#  ('Japanese_ukiyo_e', 0.4114716649055481),
#  ('artfully_rendered', 0.4093511998653412),
#  ('single_handedly_redefined', 0.40907853841781616),
#  ('pinnacles', 0.4084741473197937),
#  ('soundscape', 0.4083899259567261),
#  ('picturesque', 0.40753063559532166),
#  ('Deadly_Premonition', 0.40722501277923584),
#  ('comparably', 0.40678781270980835),
#  ('renderable', 0.4066419005393982),
#  ('intricately_crafted', 0.4065164029598236),
#  ('mantes', 0.4055854380130768),
#  ('wryly_humorous', 0.40555042028427124),
#  ('environments', 0.40551862120628357),
#  ('portraitures', 0.40536829829216003),
#  ('coffeetable', 0.4053131639957428),
#  ('Visually_stunning', 0.4049273729324341),
#  ('Sci_Fi', 0.4044933319091797),
#  ('Tolkien_esque', 0.4031842052936554),
#  ('powerhouse', 0.4021555185317993),
#  ('depiction', 0.40203219652175903),
#  ('scenic_backdrops', 0.40181970596313477),
#  ('pastel_portraits', 0.4004095792770386),
#  ('tipup', 0.40008679032325745),
#  ('areostyle', 0.3995574116706848),
#  ('farsakh', 0.3984547555446625),
#  ('looky', 0.3979295492172241),
#  ('neo_classical_architecture', 0.3977753520011902),
#  ('illustrations', 0.3974909782409668),
#  ('greats', 0.3972168564796448),
#  ('Sandlot_Games_boasts', 0.39703452587127686),
#  ('kln', 0.39666658639907837),
#  ('hypoactive', 0.3960804045200348),
#  ('cinematic_adaptations', 0.39577898383140564),
#  ('DECA_SPORTS_TM', 0.39503493905067444),
#  ('Italian_giallo', 0.3943622410297394),
#  ('richly_evocative', 0.39433449506759644),
#  ('storytelling', 0.3931756019592285),
#  ('sumptuous_visuals', 0.3923521637916565),
#  ('Jean_Stoick', 0.39011693000793457),
#  ('wonderfully_evocative', 0.3898245692253113),
#  ('cross_pollinations', 0.38937899470329285),
#  ('thornfield', 0.38846153020858765),
#  ('breathtaking_visuals', 0.3884459137916565),
#  ('woodcut_illustrations', 0.3883606791496277),
#  ('musical_extravaganzas', 0.38825103640556335),
#  ('sheet', 0.3874381184577942),
#  ('Dragon_Nest', 0.3870008885860443),
#  ('shôjo', 0.38692861795425415),
#  ('Lanky_brooding_Superman', 0.3866126537322998),
#  ('juxtaposition', 0.3861512839794159),
#  ('austerely_beautiful', 0.3860107660293579),
#  ('breathtaking', 0.3859516382217407),
#  ('composer_Koichi_Sugiyama', 0.38487717509269714),
#  ('western', 0.38479846715927124),
#  ('endlessly_replayable', 0.38447389006614685),
#  ('artwork', 0.3841504454612732),
#  ('THE_SIMPSONS_GAME', 0.3838580846786499),
#  ('mountainscapes', 0.38328707218170166),
#  ('Cinematically', 0.38321012258529663),
#  ('paintings_depict', 0.38319721817970276),
#  ('unparalleled', 0.38284122943878174),
#  ('picturebook', 0.3825337588787079),
#  ('crowning_glories', 0.3822958767414093),
#  ('surrealist_imagery', 0.38196176290512085),
#  ('Superhero_Movie_spoof', 0.38154417276382446),
#  ('uniquely', 0.38121113181114197),
#  ('aslop', 0.3804466426372528),
#  ('Sega_Superstars_Tennis', 0.38028618693351746),
#  ('artistic_creations', 0.3800619840621948),
#  ('landscapes', 0.37977325916290283),
#  ('forefathers', 0.3796738386154175),
#  ('hyper_realism', 0.3796173930168152),
#  ('blocky', 0.37960284948349),
#  ('suitably', 0.3795316815376282),
#  ('psychological', 0.3789810836315155),
#  ('vibrantly_colorful', 0.37820324301719666),
#  ('picturesque_backdrops', 0.3780362606048584)]

# %%
my_model.model.most_similar("assassin_creed_brotherhood", topn=100)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-248-ddaa4db2d2d0> in <module>
# ----> 1 my_model.model.most_similar("assassin_creed_brotherhood", topn=100)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/gensim/utils.py in new_func1(*args, **kwargs)
#    1445                     stacklevel=2
#    1446                 )
# -> 1447                 return func(*args, **kwargs)
#    1448
#    1449             return new_func1
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/gensim/models/base_any2vec.py in most_similar(self, positive, negative, topn, restrict_vocab, indexer)
#    1395
#    1396         """
# -> 1397         return self.wv.most_similar(positive, negative, topn, restrict_vocab, indexer)
#    1398
#    1399     @deprecated("Method will be removed in 4.0.0, use self.wv.wmdistance() instead")
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/gensim/models/keyedvectors.py in most_similar(self, positive, negative, topn, restrict_vocab, indexer)
#     551                 mean.append(weight * word)
#     552             else:
# --> 553                 mean.append(weight * self.word_vec(word, use_norm=True))
#     554                 if word in self.vocab:
#     555                     all_words.add(self.vocab[word].index)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/gensim/models/keyedvectors.py in word_vec(self, word, use_norm)
#     466             return result
#     467         else:
# --> 468             raise KeyError("word '%s' not in vocabulary" % word)
#     469
#     470     def get_vector(self, word):
#
# KeyError: "word 'assassin_creed_brotherhood' not in vocabulary"

# %%
tops_nn = {
    'facets': None,
    'facet': None,
    'game': None,
    'games': None,
    'mode': None,
    'modes': None,
    'adjective': None,
    'collection': None,
    'descriptor': None,
    'description': None,
    'gametype': None,  # GOOD ONE FOR 4- identify types of games
    'classification': None,
    'experience': None,
    'category': None,
    'genre': None,
    'genres': None,
    'gametypes': None,
    'multiplayer': None,
    'characteristics': None,
    'gameplay': None,
    'aspects': None,
    'features': None,   # GOOD ONE FOR 2- identify aspects (features) of a game
    'feature': None,
    'mechanics': None,
    'style': None,
    'cool': None,
    'awesome': None,
    'boring': None,
    'soundtrack': None,
    'elements': None,
    'storyline': None,
    'graphics': None,
    'graphic': None,
    'developer': None,
    'developers': None,
    'artwork': None,
    'music': None,
    'sound': None,
}
for top in tops_nn:
    tops_nn[top] = my_model.model.most_similar(top, topn=100)
    top_words = np.array(tops_nn[top])[:, 0].tolist()
    scores = np.array(tops_nn[top])[:, 1].tolist()
    top_words = [parse(str(k) + "\n") for k in top_words]
    top_nn_indices = [i for i, x in enumerate(top_words) if x.split("/")[1] in ["NN", "NNS"] and x.split("/")[0].lower() == x.split("/")[0]]

    top_words = np.concatenate((np.array([top_words[i].split("/")[0] for i in top_nn_indices]).reshape(-1, 1), 
                                np.array([np.round(float(scores[i]), 3) for i in top_nn_indices]).reshape(-1, 1)), 1)
    tops_nn[top] = pd.DataFrame(top_words, columns=["word", "similarity"])

# %%
tops_nn['mode'][:20]
# Out:
#                word similarity
# 0             modes      0.421
# 1       SUMOylation      0.382
# 2             Modes      0.375
# 3       PvP_battles      0.368
# 4        genialness      0.361
# 5               pvp       0.36
# 6            versus      0.358
# 7              geth      0.358
# 8              coop      0.358
# 9        challenges      0.356
# 10      matchmaking      0.355
# 11    freeplay_mode      0.354
# 12         gametype      0.353
# 13  deathmatch_mode      0.353
# 14         gamelote      0.353
# 15     Singleplayer      0.353
# 16     difficulties      0.349
# 17              fun      0.347
# 18        gametypes      0.347
# 19             modo      0.346

# %%
tops_nn['mechanics'][:20]
# Out:
#                      word similarity
# 0                elements      0.479
# 1                concepts      0.455
# 2                controls       0.42
# 3                mechanic      0.419
# 4                features       0.41
# 5                 aspects      0.403
# 6   pneumatics_hydraulics       0.39
# 7                 tactics      0.388
# 8              animations      0.386
# 9                dynamics      0.382
# 10                  ideas      0.382
# 11                micerun      0.379
# 12                physics      0.379
# 13                  parts      0.377
# 14              additions      0.375
# 15      carpentry_joinery      0.373
# 16                indrawn      0.371
# 17                visuals       0.37
# 18  hydraulics_pneumatics      0.369
# 19    Pistorius_sprinting      0.369

# %%
tops_nn['features'][:20]
# Out:
#                      word similarity
# 0                elements      0.505
# 1                  tweaks      0.462
# 2               additions      0.453
# 3                 aspects      0.448
# 4                   ideas      0.438
# 5           functionality      0.416
# 6               mechanics       0.41
# 7                  things      0.408
# 8                concepts      0.404
# 9              challenges      0.397
# 10           Tall_grasses      0.396
# 11        functionalities      0.391
# 12    tools_meganucleases      0.389
# 13        rat_burrows_rat      0.389
# 14                content      0.387
# 15              Bug_fixes      0.386
# 16                  modes      0.385
# 17    Volcano_IVUS_offers      0.382
# 18  survival_marksmanship      0.382
# 19              toolsuite      0.382

# %%
tops_nn['gametypes'][:30]
# Out:
#                           word similarity
# 0                     gametype      0.771
# 1              deathmatch_mode      0.689
# 2                     loadouts      0.678
# 3   Deathmatch_Team_Deathmatch      0.676
# 4                     mutators      0.669
# 5                  mulitplayer      0.668
# 6                 deathmatches      0.661
# 7                  killstreaks      0.656
# 8                    playstyle      0.655
# 9                   playstyles      0.654
# 10                Singleplayer      0.654
# 11           multiplayer_modes      0.652
# 12                    gameplay      0.644
# 13             gameplay_tweaks      0.644
# 14                 multiplayer      0.642
# 15               Gameplay_wise      0.642
# 16            multiplayer_mode      0.639
# 17                  PvP_arenas      0.637
# 18       Achievements_Trophies      0.637
# 19                    powerups      0.635
# 20     splitscreen_multiplayer      0.631
# 21                  Deathmatch      0.629
# 22          gameplay_mechanics      0.628
# 23                singleplayer      0.625
# 24          killstreak_rewards      0.623
# 25             branching_paths      0.622
# 26                       mechs      0.621
# 27           Multiplayer_modes      0.618
# 28                  deathmatch      0.618
# 29                     AI_bots      0.617

# %%
tops_nn['music'][:10]
# Out:
#                        word similarity
# 0                soundtrack      0.577
# 1                     tunes      0.521
# 2  acoustic_instrumentation      0.505
# 3          sonic_landscapes      0.497
# 4         soothing_melodies      0.491
# 5                     sound       0.49
# 6            layered_vocals      0.485
# 7                      song      0.483
# 8           soothing_melody       0.48
# 9            lilting_melody      0.478

# %%
tops_nn['developers'][:10]
# Out:
#          word similarity
# 0        devs      0.674
# 1   developer      0.552
# 2         dev      0.546
# 3    creators       0.49
# 4      makers      0.397
# 5    throutle      0.393
# 6      people      0.391
# 7  Developers      0.389
# 8       valve      0.386
# 9      vilans      0.385

# %%
tops_nn['graphics'][:10]
# Out:
#                               word similarity
# 0                         graphics       0.56
# 1                      pixellation      0.442
# 2                       pixilation      0.437
# 3                   alpha_blending      0.437
# 4                 JPEG_compression      0.431
# 5                    bitmap_images      0.428
# 6                   font_smoothing       0.42
# 7                   polygon_counts      0.414
# 8                          visuals      0.412
# 9          teacher_Rizwanur_Rehman      0.411
# 10                         duotone       0.41
# 11                 bitmap_graphics      0.408
# 12                parallax_mapping      0.407
# 13                          opnice      0.406
# 14                  moire_patterns      0.406
# 15  SteadyShot_image_stabilization      0.403
# 16                        diagrams      0.403
# 17                    unsharp_mask      0.402
# 18                gamma_correction      0.401
# 19                             cel        0.4
# 20                      graininess      0.399
# 21                grayscale_images      0.398
# 22                      typography      0.397
# 23                      pixelation      0.397
# 24                      macroblock      0.397
# 25                             gfx      0.396
# 26         teacher_Rizwanur_Rahman      0.395
# 27                       halftones      0.393
# 28                             gpu      0.392
# 29                         clipart       0.39

# %%
tops_nn['soundtrack'][:10]
# Out:
#                         word similarity
# 0                      music      0.577
# 1                     vocals      0.515
# 2                    artwork      0.488
# 3                  storyline      0.475
# 4                 atmosphere      0.467
# 5            falsetto_vocals      0.467
# 6             cinematography      0.465
# 7     inventive_choreography      0.461
# 8             lush_harmonies       0.46
# 9           ambient_textures      0.459
# 10        moody_atmospherics      0.459
# 11                 sountrack      0.456
# 12      acoustic_guitar_riff      0.454
# 13            layered_vocals      0.454
# 14          crashing_cymbals      0.454
# 15  acoustic_instrumentation      0.453
# 16        falsetto_harmonies      0.453
# 17                 pixelovej       0.45
# 18        lush_orchestration      0.449
# 19                  composer      0.449
# 20                  melodies      0.449
# 21                  haunting      0.448
# 22     orchestral_interludes      0.448
# 23            modal_melodies      0.448
# 24                piano_riff      0.448
# 25       ambient_soundscapes      0.447
# 26                   visuals      0.446
# 27          sonic_landscapes      0.446
# 28            sonic_textures      0.444
# 29                     tunes      0.444

# %%
tops_nn['gametype'][:20]
# 집짓는다 google translate: Build a house in korean
# Out:
#                      word similarity
# 0               gametypes      0.771
# 1         deathmatch_mode      0.731
# 2              Deathmatch      0.679
# 3              deathmatch      0.675
# 4                loadouts      0.672
# 5             mulitplayer      0.666
# 6            deathmatches      0.662
# 7           Gameplay_wise      0.658
# 8   Achievements_Trophies      0.654
# 9               playstyle      0.651
# 10               mutators       0.65
# 11          dungeon_crawl      0.644
# 12              roguelike      0.639
# 13            multiplayer      0.636
# 14            killstreaks      0.636
# 15      Multiplayer_modes      0.635
# 16       multiplayer_mode      0.634
# 17           Singleplayer      0.633
# 18                ruleset      0.632
# 19       Squad_Deathmatch       0.63

# %%
tops_nn['multiplayer'][:20]
# Out:
#                             word similarity
# 0                   singleplayer      0.442
# 1               multiplayer_mode      0.437
# 2                        AI_bots      0.435
# 3                    matchmaking      0.422
# 4                       gameplay      0.417
# 5                     resalution      0.414
# 6                           game       0.41
# 7                           coop      0.399
# 8                        configs      0.397
# 9                      iWork.com      0.395
# 10       splitscreen_multiplayer      0.394
# 11             Yahoo_Nasdaq_YHOO      0.393
# 12                      campaign      0.393
# 13                   Live_Spaces      0.392
# 14              Zimbra_Documents       0.39
# 15                       offline       0.39
# 16  cooperative_multiplayer_mode      0.387
# 17               mapping_mashups      0.386
# 18                         iDisk      0.386
# 19               Sharing_Folders      0.385

# %%
tops_nn['storyline'][:10]
# Out:
#                     word similarity
# 0                  story       0.62
# 1                   plot      0.539
# 2               subplots      0.481
# 3              backstory       0.48
# 4             soundtrack      0.475
# 5               gameplay      0.448
# 6             storylines      0.442
# 7                subplot      0.439
# 8                 mythos      0.438
# 9                artwork      0.423
# 10               stories      0.422
# 11              campaign      0.421
# 12           plot_twists      0.414
# 13       convoluted_plot      0.414
# 14     freeform_gameplay       0.41
# 15        character_arcs       0.41
# 16          storytelling      0.406
# 17           protagonist      0.402
# 18            atmosphere      0.401
# 19                  game      0.399
# 20     romantic_subplots      0.399
# 21               xdsobre      0.394
# 22   gripping_storylines      0.394
# 23  cinematic_interludes      0.394
# 24               journey      0.393
# 25          gamegameplay      0.392
# 26               puzzles      0.388
# 27               graffic      0.385
# 28             metaphors      0.385
# 29         customzations      0.384

# %% [markdown]
# # Identify Games

# %%
tops_games = {
    'Borderlands': None,
    'Super_Meat_Boy': None,
    'soundtrack': None,
    'multiplayer': None,
    'characteristics': None,
    'gameplay': None,   # Good example for 3- find adjectives (or other information) characteristics of a facet of a game
    'Singleplayer': None,   # Good example for 3- find adjectives (or other information) characteristics of a facet of a game
    'singleplayer': None,   # Good example for 3- find adjectives (or other information) characteristics of a facet of a game
    'FF7': None,
    'rts': None,
}
for top in tops_games:
    tops_games[top] = my_model.model.most_similar(top, topn=100)
    top_words = np.array(tops_games[top])[:, 0].tolist()
    scores = np.array(tops_games[top])[:, 1].tolist()
    
    # x.split("/")[0].lower() == x.split("/")[0] removes Caps as they are usually noise and not adjectives
    top_games_indices = [i for i, x in enumerate(top_words) if x.lower() != x]

    top_words = np.concatenate((np.array([top_words[i].split("/")[0] for i in top_games_indices]).reshape(-1, 1), 
                                np.array([np.round(float(scores[i]), 3) for i in top_games_indices]).reshape(-1, 1)), 1)
    tops_games[top] = pd.DataFrame(top_words, columns=["words", "similarity"])

# %%
# Games known for their multiplayer mode (not all terms are Games, but some are)
tops_games['Singleplayer'][:10]
# Out:
#                 words similarity
# 0  Online_Multiplayer      0.711
# 1    Multiplayer_Demo      0.705
# 2       Metal_Slug_XX      0.704
# 3   Multiplayer_Modes      0.703
# 4       CoD_Black_Ops      0.694
# 5      Onslaught_Mode      0.693
# 6    Multiplayer_Maps      0.685
# 7         Multiplayer      0.684
# 8         Patch_v#.##      0.682
# 9                X###      0.679

# %%
tops_games['singleplayer'][:10]
# Out:
#              words similarity
# 0   Firefight_mode      0.673
# 1      Multiplayer      0.672
# 2       Kane_Wrath      0.669
# 3     Singleplayer      0.661
# 4              RE5       0.66
# 5       Multiwinia      0.652
# 6  Perseus_Mandate      0.647
# 7          E3_demo      0.646
# 8           Civ_IV      0.644
# 9             GRAW      0.642

# %%
# Games known for their multiplayer mode (not all terms are Games, but some are)
tops_games['multiplayer'][:50]
# Out:
#                      adjectives similarity
# 0                   Multiplayer      0.838
# 1                Firefight_mode      0.717
# 2              Multiplayer_mode        0.7
# 3                       AI_bots       0.69
# 4             Multiplayer_modes      0.688
# 5                           PvP      0.686
# 6                  StarCraft_II      0.677
# 7                    PvP_combat      0.666
# 8                    Horde_mode      0.661
# 9                      Gameplay      0.659
# 10                     Killzone      0.658
# 11                          MMO      0.653
# 12                Skirmish_mode      0.652
# 13                 RPG_gameplay       0.65
# 14  Geometry_Wars_Retro_Evolved      0.648
# 15               Fireteam_Bravo      0.648
# 16       Battlestations_Pacific      0.645
# 17                 RTS_gameplay      0.644
# 18                  BattleForge      0.643
# 19                     Spyborgs      0.642
# 20                    Xbox_Live      0.641
# 21                         MMOG      0.638
# 22                Spec_Ops_mode      0.636
# 23             Multiplayer_Mode      0.636
# 24                       EndWar      0.634
# 25                         COD4      0.633
# 26                         GRAW      0.632
# 27                          UT3      0.632
# 28       Phantasy_Star_Universe      0.631
# 29                    RTS_genre      0.631
# 30                   Halo_Reach       0.63
# 31               Battlefront_II      0.628
# 32                        Gears      0.627
# 33                  Battle_Mode      0.627
# 34                 FPS_gameplay      0.625
# 35               Gunstar_Heroes      0.625
# 36                   Motorstorm      0.625
# 37                  PvP_battles      0.624
# 38             Modern_Warfare_2      0.623
# 39                Gameplay_wise      0.622
# 40                         MMOs      0.622
# 41                   CrimeCraft      0.621
# 42              Team_Deathmatch      0.621
# 43                    FPS_genre      0.621
# 44              multiplayer_FPS       0.62
# 45             Xbox_Live_Arcade       0.62
# 46                       MMORPG      0.618
# 47                   Deathmatch      0.617
# 48                 Chromehounds      0.617
# 49                         XBLA      0.617

# %%
# Games known for there good gameplay?
tops_games['gameplay'][:50]
# Out:
#                  adjectives similarity
# 0                  Gameplay      0.791
# 1             Gameplay_wise      0.729
# 2              RPG_gameplay      0.719
# 3               Multiplayer      0.715
# 4                 FPS_genre      0.713
# 5            Firefight_mode        0.7
# 6              FPS_gameplay      0.699
# 7             2D_platformer      0.692
# 8                 RTS_genre       0.69
# 9              Ninja_Gaiden      0.687
# 10                     GRAW      0.683
# 11              Alien_Breed      0.683
# 12                 Killzone      0.681
# 13  Dynasty_Warriors_Gundam      0.678
# 14             Chromehounds      0.678
# 15                RPG_genre      0.677
# 16             RTS_gameplay      0.675
# 17                      GoW      0.674
# 18                  E3_demo      0.674
# 19          Crystal_Bearers      0.673
# 20           Gunstar_Heroes      0.673
# 21                 Spyborgs      0.671
# 22   Space_Invaders_Extreme      0.667
# 23           Battlefront_II      0.666
# 24   Battlestations_Pacific      0.664
# 25                     MGS3      0.661
# 26                    GTAIV       0.66
# 27          Ninja_Gaiden_II      0.658
# 28                MMO_genre      0.658
# 29              Smash_Bros.      0.657
# 30                     MGS4      0.657
# 31                 BlazBlue      0.656
# 32                     JRPG      0.655
# 33       Ninja_Gaiden_Sigma      0.655
# 34                     RPGs      0.653
# 35               CrimeCraft      0.651
# 36  Bionic_Commando_Rearmed      0.651
# 37                Galactrix      0.651
# 38                    KOTOR      0.651
# 39           Battalion_Wars       0.65
# 40                      FPS       0.65
# 41                Tenkaichi       0.65
# 42                      RPG      0.649
# 43   Valkyria_Chronicles_II      0.649
# 44                     MvC2      0.649
# 45                     SFIV      0.648
# 46                     SRPG      0.647
# 47                     XBLA      0.647
# 48              Space_Siege      0.647
# 49           Adventure_Mode      0.647

# %%
# Strangely, Dong_Dong is king of relevant because is a a Chinese Gymnast (super meat boy jumps high and stuff)
tops_games['Super_Meat_Boy'][:50]
# Out:
#                adjectives similarity
# 0     Ben_Hur_proportions      0.469
# 1           Mortal_Combat      0.468
# 2            BY_GAIL_WOOD      0.449
# 3  Milli_Vanilli_Orlowski      0.446
# 4            Cold_Hearted      0.444
# 5              Mario_Kart      0.441
# 6               Dong_Dong      0.441
# 7       Quack_Quack_Quack       0.44
# 8           grit_Laimbeer      0.438
# 9         BY_TRACEY_PRISK      0.437

# %%
tops_games['Borderlands'][:50]
# Out:
#                          adjectives similarity
# 0                       Alien_Breed      0.663
# 1                        Darksiders      0.658
# 2                             GTAIV      0.655
# 3                          BioShock      0.645
# 4                              GRAW      0.637
# 5        Assassin_Creed_Brotherhood      0.636
# 6                           ArmA_II      0.636
# 7                              XBLA      0.635
# 8                        Zeno_Clash      0.635
# 9                       Bulletstorm      0.634
# 10                    General_Knoxx      0.633
# 11                         Killzone      0.633
# 12           Red_Faction_Armageddon      0.629
# 13                 Undead_Nightmare      0.628
# 14           Geometry_Wars_Galaxies      0.626
# 15                   Assault_Heroes      0.625
# 16                Dungeon_Siege_III      0.622
# 17                              UT3      0.621
# 18                        Dreamfall      0.621
# 19                     GOTY_edition       0.62
# 20                  LittleBigPlanet      0.619
# 21                  Hellgate_London      0.617
# 22           Puzzle_Quest_Galactrix      0.616
# 23                  Borderlands_DLC      0.616
# 24                    Shadowgrounds      0.614
# 25          Dynasty_Warriors_Gundam      0.614
# 26  Ghost_Recon_Advanced_Warfighter      0.613
# 27                         Bioshock      0.609
# 28                       Multiwinia      0.609
# 29             Batman_Arkham_Asylum      0.609
# 30                              RE5      0.608
# 31                             GTA4      0.606
# 32               Dragon_Age_Origins      0.606
# 33                 Modern_Warfare_2      0.606
# 34                      Demon_Souls      0.605
# 35       Splinter_Cell_Chaos_Theory      0.605
# 36                             MGS4      0.605
# 37                           GTA_IV      0.605
# 38                     Auto_Assault      0.605
# 39                     Bullet_Witch      0.604
# 40            Blacklight_Tango_Down      0.604
# 41                 Warhammer_Online      0.603
# 42                       Motorstorm      0.603
# 43                Twilight_Princess      0.602
# 44                 Xbox_Live_Arcade      0.602
# 45                   Gunstar_Heroes      0.601
# 46                       Frozenbyte        0.6
# 47                   Pocket_Legends      0.599
# 48                              MMO      0.599
# 49        Elder_Scrolls_IV_Oblivion      0.598

# %%
vocab = list(my_model.get_vocab().keys())
w = open(direc + "vocab_" + checkpoint, "w+")
with tqdm(total=len(vocab)) as pbar:
    for v in vocab:
        w.write(v + "\n")
        pbar.update(1)
w.close()

#w = open("vocab_word2vec_POS.txt", "w+")
#with tqdm(total=len(vocab)) as pbar:
#    for v in vocab:
#        w.write(tag(v) + "\n")
#        pbar.update(1)
#w.close()

w = open(checkpoint + "_parse.txt", "w+")
with tqdm(total=len(vocab)) as pbar:
    for v in vocab:
        w.write(parse(str(v) + "\n") + "\n")
        pbar.update(1)
w.close()


# These names are in game_names, obtained in draft.py from taking words before the pattern "is a * game"
# The list is small and noisy. We will take a single popular game,
# top100 = my_model.model.most_similar('Borderlands', topn=100)
# Out:
# 100%|██████████| 3048327/3048327 [00:04<00:00, 659277.07it/s]
#   1%|          | 21959/3048327 [00:09<21:18, 2367.45it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-8f0da7eed5c4> in <module>
#      17 with tqdm(total=len(vocab)) as pbar:
#      18     for v in vocab:
# ---> 19         w.write(parse(str(v) + "\n") + "\n")
#      20         pbar.update(1)
#      21 w.close()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pattern/text/en/__init__.py in parse(s, *args, **kwargs)
#     167     """ Returns a tagged Unicode string.
#     168     """
# --> 169     return parser.parse(s, *args, **kwargs)
#     170
#     171
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pattern/text/__init__.py in parse(self, s, tokenize, tags, chunks, relations, lemmata, encoding, **kwargs)
#    1158         # Tokenizer.
#    1159         if tokenize is True:
# -> 1160             s = self.find_tokens(s, **kwargs)
#    1161         if isinstance(s, (list, tuple)):
#    1162             s = [isinstance(s, str) and s.split(" ") or s for s in s]
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pattern/text/__init__.py in find_tokens(self, string, **kwargs)
#    1103               abbreviations = kwargs.get("abbreviations", ABBREVIATIONS),
#    1104                     replace = kwargs.get("replace", replacements),
# -> 1105                   linebreak = r"\n{2,}")
#    1106
#    1107     def find_tags(self, tokens, **kwargs):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pattern/text/__init__.py in find_tokens(string, punctuation, abbreviations, replace, linebreak)
#    1410             tail = []
#    1411             if not RE_MENTION.match(t):
# -> 1412                 while t.startswith(punctuation) and \
#    1413                   t not in replace:
#    1414                     # Split leading punctuation.
#
# KeyboardInterrupt:

# %%
tops_nn['elements'][:20]
# Out:
#                      word similarity
# 0                features       0.53
# 1                 aspects      0.502
# 2               mechanics      0.477
# 3              techniques      0.472
# 4                   ideas      0.457
# 5                 поиграл      0.435
# 6                concepts      0.433
# 7                  things      0.421
# 8              influences      0.419
# 9                  วไปเเน      0.412
# 10          AJAX_toolkits      0.411
# 11         deconstruction      0.409
# 12               dynamics      0.403
# 13            intricacies        0.4
# 14           นมากเเนวเอาต      0.399
# 15  harmonic_progressions      0.399
# 16               classics      0.398
# 17                 pegada      0.396
# 18                puzzles      0.395
# 19                 themes      0.395

# %%
tops = {
    'Borderlands': None,
    'facets': None,
    'Super_Meat_Boy': None,
    'adjective': None,
    'type': None,
    'multiplayer': None,
    'characteristics': None,
    'gameplay': None,   # Good example for 3- find adjectives (or other information) characteristics of a facet of a game
    'god': None,
    'FF7': None,
    'rts': None,
}
for top in tops:
    tops[top] = my_model.model.most_similar(top, topn=1000)
    top_words = np.array(tops[top])[:, 0].tolist()
    scores = np.array(tops[top])[:, 1].tolist()
    top_words = [parse(str(k) + "\n") for k in top_words]
    
    # x.split("/")[0].lower() == x.split("/")[0] removes Caps as they are usually noise and not adjectives
    top_jj_indices = [i for i, x in enumerate(top_words) if x.split("/")[1] in ["JJ", "JJR", "JJS"] and x.split("/")[0].lower() == x.split("/")[0]]

    top_words = np.concatenate((np.array([top_words[i].split("/")[0] for i in top_jj_indices]).reshape(-1, 1), 
                                np.array([np.round(float(scores[i]), 3) for i in top_jj_indices]).reshape(-1, 1)), 1)
    tops[top] = pd.DataFrame(top_words, columns=["adjectives", "similarity"])

# %%
# Enlever les termes avec Caps ou Caps_Caps
tops["gameplay"][:30]
# Out:
#                    adjectives similarity
# 0           gameplay_mechanic      0.746
# 1                  replayable      0.654
# 2                    minigame      0.653
# 3               overworld_map      0.645
# 4                sidescroller      0.631
# 5               side_scroller      0.629
# 6           fast_paced_arcade      0.624
# 7                    metagame      0.608
# 8   side_scrolling_platformer      0.608
# 9           highly_replayable      0.607
# 10                  frag_fest      0.598
# 11                  microgame      0.592
# 12      infinitely_replayable      0.592
# 13                     ingame      0.591
# 14                  videogame      0.587
# 15                   fragfest      0.569

# %%
tops["Super_Meat_Boy"][:20]
# Out:
#       adjectives similarity
# 0         noemon      0.486
# 1          owena      0.464
# 2      uncharted      0.449
# 3       stochmal      0.447
# 4        dareful       0.44
# 5         virous      0.439
# 6   appassionate      0.438
# 7      goustrous      0.437
# 8        frousty      0.435
# 9        meinong      0.435
# 10        cachot      0.434
# 11          leal       0.43
# 12        barkan      0.429
# 13       dejeune      0.428
# 14        cohune      0.427
# 15         lavic      0.427
# 16       libeler      0.426
# 17        geodic      0.425
# 18       cereous      0.424
# 19      myelonic      0.423

# %%
tops["Borderlands"][:20]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-815ef3d578c0> in <module>
# ----> 1 tops["Borderlands"][:20]
#
# NameError: name 'tops' is not defined

# %%
display_closestwords_pcascatterplot(my_model.model, "Borderlands")
display_closestwords_pcascatterplot(my_model.model, "Portals")
display_closestwords_pcascatterplot(my_model.model, "FFVII")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-660ad0de7edf> in <module>
# ----> 1 display_closestwords_pcascatterplot(my_model.model, "Borderlands")
#       2 display_closestwords_pcascatterplot(my_model.model, "Portals")
#       3 display_closestwords_pcascatterplot(my_model.model, "FFVII")
#
# NameError: name 'display_closestwords_pcascatterplot' is not defined
