# %%
import os

# The notebook is a subfolder, must go back to parent folder
# Note that if if cell is executed twice, the remaining cells
# will fail because the current working directory will be wrong
os.chdir("..")

# %%
from src.vectorize import EmbeddingsModel
from tqdm import tqdm
import numpy as np
from pattern.text.en import parse
import pandas as pd
import jsbeautifier
from src.scrape import build_dataframe, normalize_csv, is_a_game, unique_games, get_review, games_abbreviation, look_for_games, get_user_ids

# %% [markdown]
# # Part I: Identify a few games
#
# With word embeddings, a lot of games can be found automatically.
# However, before doing so, we need to identify some games first (we will assume we know none of the games that are being reviewed).

# %%
if scrape_games:
    is_a_game()
    unique_games()
    games_abbreviation()
    look_for_games()
# Out:
# Finding games...

# %% [markdown]
# # Part II: Create a dataframe
#
# All the relevant information within the json file will be organised into a well-organised pandas DataFrame to make all subsequent steps easier.
#
# The Dataframe will be saved as a csv file which can be reloaded later to accelerate the process.

# %% [markdown]
# The following step needs only to be done once per corpus

# %%
make_csv = True
if make_csv:
    build_dataframe()
    normalize_csv()
# Out:
#   0%|          | 0/25799 [00:00<?, ?it/s]
# Building the dataframe in extracted/dataframes...
# 100%|██████████| 25799/25799 [14:18<00:00, 30.05it/s]
# Normalizing csv...
# Normalizing text...
#   0%|          | 0/466544 [00:00<?, ?it/s]
# Creating dictionary for symspell
# Creating Dictionary from array...
#  60%|██████    | 280980/466544 [03:18<02:11, 1415.70it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-476c6c713e45> in <module>
#       2 if make_csv:
#       3     build_dataframe()
# ----> 4     normalize_csv()
#
# ~/Desktop/steam_scraping/src/scrape.py in normalize_csv(df_name, norm_fname, spell_check)
#     291             eng_words = [word.strip() for word in words]
#     292             print('Creating dictionary for symspell')
# --> 293             _ = ss.create_dictionary_from_arr(eng_words, token_pattern=r'.+')
#     294             words_dict = {k: 0 for k in eng_words}
#     295             with tqdm(total=len(df)) as pbar:
#
# ~/Desktop/steam_scraping/src/preprocess.py in create_dictionary_from_arr(self, arr, token_pattern)
#     396                 for word in words:
#     397                     total_word_count += 1
# --> 398                     if self.create_dictionary_entry(word):
#     399                         unique_word_count += 1
#     400                 pbar.update(1)
#
# ~/Desktop/steam_scraping/src/preprocess.py in create_dictionary_entry(self, w)
#     372             # in those cases)
#     373             new_real_word_added = True
# --> 374             deletes = self.get_deletes_list(w)
#     375             for item in deletes:
#     376                 if item in self.dictionary:
#
# ~/Desktop/steam_scraping/src/preprocess.py in get_deletes_list(self, w)
#     344                     for c in range(len(word)):  # character index
#     345                         word_minus_c = word[:c] + word[c + 1:]
# --> 346                         if word_minus_c not in deletes:
#     347                             deletes.append(word_minus_c)
#     348                         if word_minus_c not in temp_queue:
#
# KeyboardInterrupt:

# %% [raw]
# # what happens in build_dataframe
# make_csv = True
# filepath = 'data/australian_user_reviews.json'
# scrape_games = True
# if make_csv:
#     w = open("extracted/lists/australian_user_reviews.txt", "w+")
#     names_file = "extracted/lists/games_abbreviations.txt"
#     names = pd.read_csv(names_file, names=["names", "abbr"])
#     reviews = []
#     ids = []
#     funnys = []
#     helpfuls = []
#     recommends = []
#     polarities = []
#     positives = []
#     subjectivities = []
#     with tqdm(total=25799) as pbar:
#         with open(filepath) as fp:
#             for cnt, line in enumerate(fp):
#                 line = jsbeautifier.beautify(line)
#                 revs, polars, positivs, subjs, funs, helps, recoms = get_review(line, cnt)
#                 reviews.extend(revs)
#                 polarities.extend(polars)
#                 positives.extend(positivs)
#                 subjectivities.extend(subjs)
#                 ids.extend([get_user_ids(line, cnt) for _ in range(len(revs))])
#                 funnys.extend(funs)
#                 helpfuls.extend(helps)
#                 recommends.extend(recoms)
#
#                 w.write(reviews[-1] + '\n')
#                 pbar.update(1)
#     w.close()
#     ids = np.array(ids)
#     funnys = np.array(funnys)
#     helpfuls = np.array(helpfuls)
#     recommends = np.array(recommends)
#     reviews = np.array(reviews)
#     polarities = np.array(polarities)
#     positives = np.array(positives)
#     subjectivities = np.array(subjectivities)
#     df = pd.DataFrame(columns=["id",
#                                "funny",
#                                "helpful",
#                                "recommend",
#                                "polarity",
#                                "positive",
#                                "subjectivity",
#                                "review"],
#                       data=np.concatenate((ids.reshape(-1, 1),
#                                            funnys.reshape(-1, 1),
#                                            helpfuls.reshape(-1, 1),
#                                            recommends.reshape(-1, 1),
#                                            polarities.reshape(-1, 1),
#                                            positives.reshape(-1, 1),
#                                            subjectivities.reshape(-1, 1),
#                                            reviews.reshape(-1, 1)), 1))
#     df.to_csv("steam_australia.csv", index=False)

# %% [markdown]
# ### Find The most mentionned games among the ones that were found

# %%
scraped_games = pd.read_table("extracted/lists/game_lines.csv", sep='[')
scraped_games.columns = ["Game", "mentions"]
games = np.array(scraped_games["Game"])
games = np.array([g.strip(",") for g in games])
scraped_games["Game"] = games

new_df = pd.DataFrame(index=games, data=np.array([None for _ in games]).reshape(-1, 1), columns=["n_mentions"])
for i, key in enumerate(range(len(scraped_games["Game"]))):
    new_df["n_mentions"][i] = len(scraped_games["mentions"][i].split(","))

# %%
# There is some noise: The Game, Well There, The Launcher et Now 
# Insurgency Really is about a game called Insurgency

new_df = new_df.sort_values(by=['n_mentions'], ascending=False)
new_df[:20]
# Out:
#                                 n_mentions
# Team Fortress 2                        251
# Nuclear Throne                         232
# Dont Starve                             86
# Dota 2                                  79
# Insurgency Really                       65
# Portal                                  51
# Sonic Generations                       49
# Counter Strike Global Offensive         43
# Well There                              36
# The Culling                             27
# Garrys Mod                              26
# The Community                           24
# Starbound                               22
# Sanctum 2                               20
# Tf2                                     19
# Half Life 2                             17
# Undertale                               16
# Cs:go                                   11
# Loadout                                 10
# Evolve                                   8

# %% [markdown]
# # Part III: Identify word embeddings (word2vec)

# %%
my_model = EmbeddingsModel()
train = False
direc = "saved_models/"
checkpoint = "gensim_model_pretrainedGoogleNews-vectors-negative300.bin.model"
if train:
    my_model.train("steam_australia_norm_w2v.csv", checkpoint=direc + "GoogleNews-vectors-negative300.bin")
    my_model.save_model(checkpoint)
my_model.load_model(direc + checkpoint)
# Out:
# 2019-12-17 17:21:38,169 : INFO : loading Word2Vec object from saved_models/gensim_model_pretrainedGoogleNews-vectors-negative300.bin.model
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-dc708c9b63ac> in <module>
#       6     my_model.train("steam_australia_norm_w2v.csv", checkpoint=direc + "GoogleNews-vectors-negative300.bin")
#       7     my_model.save_model(checkpoint)
# ----> 8 my_model.load_model(direc + checkpoint)
#
# ~/Desktop/steam_scraping/src/vectorize.py in load_model(self, absolute_path)
#     163
#     164     def load_model(self, absolute_path):
# --> 165         self.model = gensim.models.Word2Vec.load(absolute_path)
#     166
#     167     def make_word2vec(self, absolute_path):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/gensim/models/word2vec.py in load(cls, *args, **kwargs)
#    1328         """
#    1329         try:
# -> 1330             model = super(Word2Vec, cls).load(*args, **kwargs)
#    1331
#    1332             # for backward compatibility for `max_final_vocab` feature
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/gensim/models/base_any2vec.py in load(cls, *args, **kwargs)
#    1242
#    1243         """
# -> 1244         model = super(BaseWordEmbeddingsModel, cls).load(*args, **kwargs)
#    1245         if not hasattr(model, 'ns_exponent'):
#    1246             model.ns_exponent = 0.75
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/gensim/models/base_any2vec.py in load(cls, fname_or_handle, **kwargs)
#     601
#     602         """
# --> 603         return super(BaseAny2VecModel, cls).load(fname_or_handle, **kwargs)
#     604
#     605     def save(self, fname_or_handle, **kwargs):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/gensim/utils.py in load(cls, fname, mmap)
#     424         compress, subname = SaveLoad._adapt_by_suffix(fname)
#     425
# --> 426         obj = unpickle(fname)
#     427         obj._load_specials(fname, mmap, compress, subname)
#     428         logger.info("loaded %s", fname)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/gensim/utils.py in unpickle(fname)
#    1379
#    1380     """
# -> 1381     with open(fname, 'rb') as f:
#    1382         # Because of loading from S3 load can't be used (missing readline in smart_open)
#    1383         if sys.version_info > (3, 0):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/smart_open/smart_open_lib.py in open(uri, mode, buffering, encoding, errors, newline, closefd, opener, ignore_ext, transport_params)
#     306         buffering=buffering,
#     307         encoding=encoding,
# --> 308         errors=errors,
#     309     )
#     310     if fobj is not None:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/smart_open/smart_open_lib.py in _shortcut_open(uri, mode, ignore_ext, buffering, encoding, errors)
#     515     #
#     516     if six.PY3:
# --> 517         return _builtin_open(parsed_uri.uri_path, mode, buffering=buffering, **open_kwargs)
#     518     elif not open_kwargs:
#     519         return _builtin_open(parsed_uri.uri_path, mode, buffering=buffering)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'saved_models/gensim_model_pretrainedGoogleNews-vectors-negative300.bin.model'

# %%
tops_games = {
    'Borderlands': None,
    'borderlands': None,
    'FFIV': None,
    'fortress': None,
}
for top in tops_games:
    tops_games[top] = my_model.model.most_similar(top, topn=100)
    tops_games[top] = pd.DataFrame(tops_games[top], columns=["word", "similarity"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-23629891cc33> in <module>
#       6 }
#       7 for top in tops_games:
# ----> 8     tops_games[top] = my_model.model.most_similar(top, topn=100)
#       9     tops_games[top] = pd.DataFrame(tops_games[top], columns=["word", "similarity"])
#
# NameError: name 'my_model' is not defined

# %%
tops_games['borderlands'][:20]
# Out:
#                     word  similarity
# 0               bioshock    0.470961
# 1               mexicana    0.405006
# 2        indium_enriched    0.402543
# 3                 sangre    0.398689
# 4                  creed    0.394627
# 5                 portal    0.393190
# 6              rebellion    0.391285
# 7                     bl    0.390408
# 8               original    0.389454
# 9             borderland    0.383267
# 10               combina    0.380638
# 11              ziggurat    0.380528
# 12  Larry_McMurtry_novel    0.378102
# 13     Dissenters_Nation    0.376549
# 14              plotwise    0.375469
# 15               fallout    0.375114
# 16   Beautifully_crafted    0.375059
# 17               witcher    0.372975
# 18                   rog    0.372106
# 19                 lapis    0.371562

# %%
my_model.model.most_similar("Bioshock", topn=100)
# Out:
# [('BioShock', 0.8794984817504883),
#  ('Killzone', 0.7690650820732117),
#  ('GoW', 0.7541419267654419),
#  ('Crysis', 0.7426438927650452),
#  ('Metroid_Prime', 0.7352886199951172),
#  ('Timesplitters', 0.7320432066917419),
#  ('Mass_Effect', 0.7320175170898438),
#  ('Mario_Galaxy', 0.7282251119613647),
#  ('Assassin_Creed', 0.7241993546485901),
#  ('GTAIV', 0.7229788303375244),
#  ('Modern_Warfare', 0.7205285429954529),
#  ('GTA4', 0.7203500270843506),
#  ('Dead_Space', 0.7179621458053589),
#  ('Darksiders', 0.7170871496200562),
#  ('Alien_Breed', 0.7164978981018066),
#  ('Dynasty_Warriors_Gundam', 0.7117792963981628),
#  ('Bungie_Halo', 0.7100509405136108),
#  ('Far_Cry', 0.7091567516326904),
#  ('Resident_Evil', 0.7088419198989868),
#  ('Geometry_Wars', 0.705782949924469),
#  ('Twilight_Princess', 0.701901912689209),
#  ('GTA_IV', 0.7005239725112915),
#  ('Modern_Warfare_2', 0.6992732882499695),
#  ('Ghost_Recon_Advanced_Warfighter', 0.6985984444618225),
#  ('Dragon_Age', 0.6985704898834229),
#  ('PixelJunk_Shooter', 0.6982147097587585),
#  ('Final_Fantasy_XII', 0.6968674063682556),
#  ('MGS4', 0.6952660083770752),
#  ('TimeSplitters', 0.6948279142379761),
#  ('inFAMOUS', 0.6922991871833801),
#  ('Uncharted', 0.6910265684127808),
#  ('Splinter_Cell_Chaos_Theory', 0.6900743842124939),
#  ('Puzzle_Quest', 0.6896520853042603),
#  ('Dungeon_Siege', 0.6892951726913452),
#  ('Assassins_Creed', 0.6892677545547485),
#  ('Psychonauts', 0.6891082525253296),
#  ('Elder_Scrolls_Oblivion', 0.6886844635009766),
#  ('Infinity_Ward_Modern_Warfare', 0.688678503036499),
#  ('Unreal_Championship', 0.6872129440307617),
#  ('Elder_Scrolls', 0.6862713098526001),
#  ('Deus_Ex', 0.6861318945884705),
#  ('Mirror_Edge', 0.6859849095344543),
#  ('Marvel_Vs_Capcom', 0.6840993762016296),
#  ('Castle_Crashers', 0.6836007833480835),
#  ('RE5', 0.6824063062667847),
#  ('Heavenly_Sword', 0.6816854476928711),
#  ('Fatal_Frame', 0.6806915998458862),
#  ('Dead_Rising', 0.6796281337738037),
#  ('LittleBigPlanet', 0.6786879897117615),
#  ('Super_Metroid', 0.6781979203224182),
#  ('KOTOR', 0.6779335737228394),
#  ('Valkyrie_Profile', 0.6777811050415039),
#  ('Elder_Scrolls_IV_Oblivion', 0.6774169206619263),
#  ('Ninja_Gaiden_Sigma', 0.6769893169403076),
#  ('Batman_Arkham_Asylum', 0.676740288734436),
#  ('DMC4', 0.6764323711395264),
#  ('PSN_XBLA', 0.6764013767242432),
#  ('Demon_Souls', 0.6752605438232422),
#  ('Dead_Space_Extraction', 0.6720790266990662),
#  ('Ninja_Blade', 0.6719985008239746),
#  ('Nanostray', 0.6717655658721924),
#  ('Titan_Quest', 0.671205461025238),
#  ('Castlevania', 0.6709870100021362),
#  ('Saints_Row', 0.6708096265792847),
#  ('Space_Invaders_Extreme', 0.6706470251083374),
#  ('Starcraft_Ghost', 0.670573353767395),
#  ('FFXII', 0.6699848771095276),
#  ('Bionic_Commando_Rearmed', 0.6698973774909973),
#  ('Gunstar_Heroes', 0.6695287227630615),
#  ('TimeSplitters_Future_Perfect', 0.6694529056549072),
#  ('Splatterhouse', 0.6687990427017212),
#  ('FFXIII', 0.6687090992927551),
#  ('Puzzle_Quest_Galactrix', 0.6686117649078369),
#  ('Thief_Deadly_Shadows', 0.6682852506637573),
#  ('Final_Fantasy_XIII', 0.6669971942901611),
#  ('Indigo_Prophecy', 0.6668956279754639),
#  ('Eternal_Darkness', 0.6668232083320618),
#  ('Morrowind', 0.6667165756225586),
#  ('Sonic_Adventure', 0.6659479141235352),
#  ('Planescape_Torment', 0.6656972169876099),
#  ('Driv3r', 0.6655749678611755),
#  ('Ninja_Gaiden', 0.6655257940292358),
#  ('BioShock_Infinite', 0.6652045249938965),
#  ('RE4', 0.6648536920547485),
#  ('Halo', 0.6644764542579651),
#  ('Mindjack', 0.6642566919326782),
#  ('Gamecube', 0.663114070892334),
#  ('Chrono_Trigger', 0.6627657413482666),
#  ('GRAW', 0.6618591547012329),
#  ('Splinter_Cell', 0.6614910364151001),
#  ('Uncharted_Drake_Fortune', 0.6600082516670227),
#  ('Elder_Scrolls_IV', 0.6598678231239319),
#  ('Star_Wars_Battlefront', 0.6596592664718628),
#  ('Splinter_Cell_Conviction', 0.6596317887306213),
#  ('Comic_Jumper', 0.6591768264770508),
#  ('Wolfenstein', 0.658532977104187),
#  ('GTA_Chinatown_Wars', 0.6580636501312256),
#  ('Bioshock_Infinite', 0.6580082178115845),
#  ('Oddworld', 0.6578055620193481),
#  ('Valkyria_Chronicles', 0.657680869102478)]

# %%
my_model.model.most_similar("assassin_creed_brotherhood", topn=100)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-248-ddaa4db2d2d0> in <module>
# ----> 1 my_model.model.most_similar("assassin_creed_brotherhood", topn=100)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/gensim/utils.py in new_func1(*args, **kwargs)
#    1445                     stacklevel=2
#    1446                 )
# -> 1447                 return func(*args, **kwargs)
#    1448
#    1449             return new_func1
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/gensim/models/base_any2vec.py in most_similar(self, positive, negative, topn, restrict_vocab, indexer)
#    1395
#    1396         """
# -> 1397         return self.wv.most_similar(positive, negative, topn, restrict_vocab, indexer)
#    1398
#    1399     @deprecated("Method will be removed in 4.0.0, use self.wv.wmdistance() instead")
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/gensim/models/keyedvectors.py in most_similar(self, positive, negative, topn, restrict_vocab, indexer)
#     551                 mean.append(weight * word)
#     552             else:
# --> 553                 mean.append(weight * self.word_vec(word, use_norm=True))
#     554                 if word in self.vocab:
#     555                     all_words.add(self.vocab[word].index)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/gensim/models/keyedvectors.py in word_vec(self, word, use_norm)
#     466             return result
#     467         else:
# --> 468             raise KeyError("word '%s' not in vocabulary" % word)
#     469
#     470     def get_vector(self, word):
#
# KeyError: "word 'assassin_creed_brotherhood' not in vocabulary"

# %%
tops_nn = {
    'facets': None,
    'facet': None,
    'game': None,
    'games': None,
    'mode': None,
    'modes': None,
    'adjective': None,
    'collection': None,
    'descriptor': None,
    'description': None,
    'gametype': None,  # GOOD ONE FOR 4- identify types of games
    'classification': None,
    'experience': None,
    'category': None,
    'genre': None,
    'genres': None,
    'gametypes': None,
    'gamemode': None,
    'gamemodes': None,
    'multiplayer': None,
    'characteristics': None,
    'gameplay': None,
    'aspects': None,
    'features': None,   # GOOD ONE FOR 2- identify aspects (features) of a game
    'feature': None,
    'mechanics': None,
    'style': None,
    'cool': None,
    'awesome': None,
    'boring': None,
    'soundtrack': None,
    'elements': None,
    'storyline': None,
    'graphics': None,
    'graphic': None,
    'developer': None,
    'developers': None,
    'artwork': None,
    'music': None,
    'sound': None,
}
for top in tops_nn:
    tops_nn[top] = my_model.model.most_similar(top, topn=100)
    top_words = np.array(tops_nn[top])[:, 0].tolist()
    scores = np.array(tops_nn[top])[:, 1].tolist()
    top_words = [parse(str(k) + "\n") for k in top_words]
    top_nn_indices = [i for i, x in enumerate(top_words) if x.split("/")[1] in ["NN", "NNS"]]

    top_words = np.concatenate((np.array([top_words[i].split("/")[0] for i in top_nn_indices]).reshape(-1, 1), 
                                np.array([np.round(float(scores[i]), 3) for i in top_nn_indices]).reshape(-1, 1)), 1)
    tops_nn[top] = pd.DataFrame(top_words, columns=["word", "similarity"])

# %% [markdown]
# # Identify Games

# %%
tops_nn['mode'][:20]
# Out:
#                                 word similarity
# 0                              modes      0.447
# 1                      freeplay_mode      0.389
# 2                              Modes      0.386
# 3                      างๆมากมายและย      0.383
# 4                            alligns      0.382
# 5                             option      0.376
# 6                         difficulty      0.376
# 7                            mission      0.373
# 8                       difficulties      0.369
# 9                           gamemode      0.366
# 10                          missions      0.358
# 11                        simulateur      0.358
# 12                       multiplayer      0.357
# 13                             ligne      0.352
# 14                              ศนาต       0.35
# 15                        botsversus      0.343
# 16                               ffa       0.34
# 17                          training      0.339
# 18  www.syniverse.com_investorevents      0.338
# 19          I2C_compatible_interface      0.336

# %%
tops_nn['mechanics'][:20]
# Out:
#                      word similarity
# 0                elements      0.477
# 1                mechanic      0.459
# 2                concepts      0.417
# 3                dynamics      0.415
# 4                controls      0.409
# 5                features      0.404
# 6                 aspects      0.402
# 7                 visuals      0.402
# 8               machanics      0.399
# 9                   ideas      0.392
# 10              functions      0.389
# 11            intricacies      0.386
# 12                 system      0.385
# 13             animations      0.382
# 14            necrophages      0.374
# 15                physics      0.364
# 16  pneumatics_hydraulics      0.364
# 17             approaches      0.362
# 18                credets      0.361
# 19                tactics      0.361

# %%
tops_nn['features'][:20]
# Out:
#                       word similarity
# 0                 elements       0.53
# 1                  aspects      0.499
# 2                   things      0.449
# 3            functionality      0.442
# 4             possiblities      0.436
# 5          functionalities      0.436
# 6                 concepts      0.432
# 7                  gadgets      0.432
# 8                    ideas      0.427
# 9                   biomes      0.426
# 10                 content      0.422
# 11  usability_enhancements      0.421
# 12           storey_atrium      0.407
# 13         LAPACK_routines      0.405
# 14               mechanics      0.404
# 15               additions      0.404
# 16               gametypes      0.403
# 17                 feature      0.401
# 18                  funimo      0.398
# 19  iWork_'##_productivity      0.398

# %%
tops_nn['gametypes'][:30]
# Out:
#                           word similarity
# 0               pinball_tables      0.523
# 1                        modes      0.494
# 2                     gametype      0.469
# 3           gameplay_mechanics      0.467
# 4                   variations      0.461
# 5           addicting_gameplay      0.461
# 6                 CG_cutscenes       0.46
# 7           player_splitscreen      0.459
# 8             Overlord_Minions      0.455
# 9              deathmatch_mode      0.455
# 10             branching_paths      0.455
# 11                possiblities      0.453
# 12           Multiplayer_modes      0.452
# 13                 gen_visuals      0.448
# 14                Wipeout_Pure      0.448
# 15        platforming_sections      0.448
# 16  Deathmatch_Team_Deathmatch      0.447
# 17           Arkadian_Warriors      0.446
# 18                 Vital_Suits      0.445
# 19           singleplayer_mode      0.444
# 20              side_scrollers      0.443
# 21           multiplayer_modes      0.442
# 22               Gameplay_wise      0.441
# 23        platforming_gameplay      0.441
# 24     unlimited_replayability       0.44
# 25       multiplayer_minigames      0.439
# 26                      keyset      0.439
# 27                 homescreens      0.438
# 28                         ctf      0.437
# 29                  microgames      0.436

# %%
tops_nn['artwork'][:10]
# Out:
#                     word similarity
# 0             landscapes      0.533
# 1  abstract_compositions      0.523
# 2              sountrack      0.517
# 3           presentation      0.515
# 4              narration      0.504
# 5              backdrops      0.501
# 6  monochromatic_palette      0.499
# 7              pixelovej      0.499
# 8        anime_cutscenes      0.498
# 9                 tenhle      0.496

# %%
tops_nn['music'][:10]
# Out:
#                        word similarity
# 0                soundtrack      0.577
# 1                     tunes      0.521
# 2  acoustic_instrumentation      0.505
# 3          sonic_landscapes      0.497
# 4         soothing_melodies      0.491
# 5                     sound       0.49
# 6            layered_vocals      0.485
# 7                      song      0.483
# 8           soothing_melody       0.48
# 9            lilting_melody      0.478

# %%
tops_nn['developers'][:10]
# Out:
#          word similarity
# 0        devs      0.674
# 1   developer      0.552
# 2         dev      0.546
# 3    creators       0.49
# 4      makers      0.397
# 5    throutle      0.393
# 6      people      0.391
# 7  Developers      0.389
# 8       valve      0.386
# 9      vilans      0.385

# %%
tops_nn['graphics'][:10]
# Out:
#                               word similarity
# 0                         graphics       0.56
# 1                      pixellation      0.442
# 2                       pixilation      0.437
# 3                   alpha_blending      0.437
# 4                 JPEG_compression      0.431
# 5                    bitmap_images      0.428
# 6                   font_smoothing       0.42
# 7                   polygon_counts      0.414
# 8                          visuals      0.412
# 9          teacher_Rizwanur_Rehman      0.411
# 10                         duotone       0.41
# 11                 bitmap_graphics      0.408
# 12                parallax_mapping      0.407
# 13                          opnice      0.406
# 14                  moire_patterns      0.406
# 15  SteadyShot_image_stabilization      0.403
# 16                        diagrams      0.403
# 17                    unsharp_mask      0.402
# 18                gamma_correction      0.401
# 19                             cel        0.4
# 20                      graininess      0.399
# 21                grayscale_images      0.398
# 22                      typography      0.397
# 23                      pixelation      0.397
# 24                      macroblock      0.397
# 25                             gfx      0.396
# 26         teacher_Rizwanur_Rahman      0.395
# 27                       halftones      0.393
# 28                             gpu      0.392
# 29                         clipart       0.39

# %%
tops_nn['storyline'][:10]
# Out:
#                     word similarity
# 0                  story       0.62
# 1                   plot      0.539
# 2               subplots      0.481
# 3              backstory       0.48
# 4             soundtrack      0.475
# 5               gameplay      0.448
# 6             storylines      0.442
# 7                subplot      0.439
# 8                 mythos      0.438
# 9                artwork      0.423
# 10               stories      0.422
# 11              campaign      0.421
# 12           plot_twists      0.414
# 13       convoluted_plot      0.414
# 14     freeform_gameplay       0.41
# 15        character_arcs       0.41
# 16          storytelling      0.406
# 17           protagonist      0.402
# 18            atmosphere      0.401
# 19                  game      0.399
# 20     romantic_subplots      0.399
# 21               xdsobre      0.394
# 22   gripping_storylines      0.394
# 23  cinematic_interludes      0.394
# 24               journey      0.393
# 25          gamegameplay      0.392
# 26               puzzles      0.388
# 27               graffic      0.385
# 28             metaphors      0.385
# 29         customzations      0.384

# %%
tops_nn['soundtrack'][:10]
# Out:
#                         word similarity
# 0                      music      0.577
# 1                     vocals      0.515
# 2                    artwork      0.488
# 3                  storyline      0.475
# 4                 atmosphere      0.467
# 5            falsetto_vocals      0.467
# 6             cinematography      0.465
# 7     inventive_choreography      0.461
# 8             lush_harmonies       0.46
# 9           ambient_textures      0.459
# 10        moody_atmospherics      0.459
# 11                 sountrack      0.456
# 12      acoustic_guitar_riff      0.454
# 13            layered_vocals      0.454
# 14          crashing_cymbals      0.454
# 15  acoustic_instrumentation      0.453
# 16        falsetto_harmonies      0.453
# 17                 pixelovej       0.45
# 18        lush_orchestration      0.449
# 19                  composer      0.449
# 20                  melodies      0.449
# 21                  haunting      0.448
# 22     orchestral_interludes      0.448
# 23            modal_melodies      0.448
# 24                piano_riff      0.448
# 25       ambient_soundscapes      0.447
# 26                   visuals      0.446
# 27          sonic_landscapes      0.446
# 28            sonic_textures      0.444
# 29                     tunes      0.444

# %%
tops_nn['gametype'][:20]
# 집짓는다 google translate: Build a house in korean
# Out:
#                      word similarity
# 0            Singleplayer      0.586
# 1             inexistente      0.582
# 2         deathmatch_mode      0.572
# 3                    집짓는다      0.562
# 4                 AI_bots      0.558
# 5         branching_paths      0.557
# 6                  amenos      0.556
# 7                     서버로      0.552
# 8           dungeon_crawl      0.546
# 9              Deathmatch      0.545
# 10                    아니면      0.537
# 11       modes_Deathmatch      0.533
# 12  isometric_perspective      0.529
# 13          Gameplay_wise      0.525
# 14                Warzone      0.524
# 15             PvP_arenas      0.521
# 16                除左染料pvp      0.521
# 17               DropTeam      0.519
# 18           Chromehounds      0.517
# 19       multiplayer_mode      0.516

# %%
tops_nn['multiplayer'][:20]
# Out:
#                             word similarity
# 0                   singleplayer      0.442
# 1               multiplayer_mode      0.437
# 2                        AI_bots      0.435
# 3                    matchmaking      0.422
# 4                       gameplay      0.417
# 5                     resalution      0.414
# 6                           game       0.41
# 7                           coop      0.399
# 8                        configs      0.397
# 9                      iWork.com      0.395
# 10       splitscreen_multiplayer      0.394
# 11             Yahoo_Nasdaq_YHOO      0.393
# 12                      campaign      0.393
# 13                   Live_Spaces      0.392
# 14              Zimbra_Documents       0.39
# 15                       offline       0.39
# 16  cooperative_multiplayer_mode      0.387
# 17               mapping_mashups      0.386
# 18                         iDisk      0.386
# 19               Sharing_Folders      0.385

# %%
tops_nn['mode'][:20]
# Out:
#                                 word similarity
# 0                              modes      0.447
# 1                      freeplay_mode      0.389
# 2                              Modes      0.386
# 3                      างๆมากมายและย      0.383
# 4                            alligns      0.382
# 5                             option      0.376
# 6                         difficulty      0.376
# 7                            mission      0.373
# 8                       difficulties      0.369
# 9                           gamemode      0.366
# 10                          missions      0.358
# 11                        simulateur      0.358
# 12                       multiplayer      0.357
# 13                             ligne      0.352
# 14                              ศนาต       0.35
# 15                        botsversus      0.343
# 16                               ffa       0.34
# 17                          training      0.339
# 18  www.syniverse.com_investorevents      0.338
# 19          I2C_compatible_interface      0.336

# %%
tops_nn['modes'][:20]
# Out:
#                             word similarity
# 0                      gametypes      0.494
# 1              Multiplayer_modes      0.448
# 2                           mode      0.447
# 3                           maps      0.443
# 4              multiplayer_modes      0.436
# 5                        classes      0.433
# 6                branching_paths      0.433
# 7                          neste       0.43
# 8   cooperative_multiplayer_mode      0.428
# 9                  freeplay_mode      0.425
# 10                         tenso      0.423
# 11       splitscreen_multiplayer      0.422
# 12                       AI_bots      0.419
# 13                      vegimite      0.414
# 14                         types      0.414
# 15                         Modes      0.413
# 16                    playstyles      0.413
# 17                         geate      0.413
# 18                   inexistente      0.412
# 19         multiplayer_minigames      0.411

# %%
tops_nn['gamemode'][:20]
# Out:
#             word similarity
# 0     deathmatch      0.439
# 1         severs      0.427
# 2      continent      0.411
# 3       channels      0.411
# 4         versus      0.403
# 5          class      0.396
# 6      terrorist      0.394
# 7    battleblock      0.387
# 8   deathmatches      0.381
# 9       şansımız      0.378
# 10         súboj      0.375
# 11     manejamos       0.37
# 12          yaay      0.369
# 13        freehl      0.368
# 14          mode      0.366
# 15       invadir      0.364
# 16     gametypes      0.364
# 17        server      0.363
# 18     yötebilme      0.361
# 19    entretiene       0.36

# %%
vocab = list(my_model.get_vocab().keys())
w = open(direc + "vocab_" + checkpoint, "w+")
with tqdm(total=len(vocab)) as pbar:
    for v in vocab:
        w.write(v + "\n")
        pbar.update(1)
w.close()

#w = open("vocab_word2vec_POS.txt", "w+")
#with tqdm(total=len(vocab)) as pbar:
#    for v in vocab:
#        w.write(tag(v) + "\n")
#        pbar.update(1)
#w.close()

w = open(checkpoint + "_parse.txt", "w+")
with tqdm(total=len(vocab)) as pbar:
    for v in vocab:
        w.write(parse(str(v) + "\n") + "\n")
        pbar.update(1)
w.close()


# These names are in game_names, obtained in draft.py from taking words before the pattern "is a * game"
# The list is small and noisy. We will take a single popular game,
# top100 = my_model.model.most_similar('Borderlands', topn=100)
# Out:
# 100%|██████████| 3048327/3048327 [00:04<00:00, 659277.07it/s]
#   1%|          | 21959/3048327 [00:09<21:18, 2367.45it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-8f0da7eed5c4> in <module>
#      17 with tqdm(total=len(vocab)) as pbar:
#      18     for v in vocab:
# ---> 19         w.write(parse(str(v) + "\n") + "\n")
#      20         pbar.update(1)
#      21 w.close()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pattern/text/en/__init__.py in parse(s, *args, **kwargs)
#     167     """ Returns a tagged Unicode string.
#     168     """
# --> 169     return parser.parse(s, *args, **kwargs)
#     170
#     171
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pattern/text/__init__.py in parse(self, s, tokenize, tags, chunks, relations, lemmata, encoding, **kwargs)
#    1158         # Tokenizer.
#    1159         if tokenize is True:
# -> 1160             s = self.find_tokens(s, **kwargs)
#    1161         if isinstance(s, (list, tuple)):
#    1162             s = [isinstance(s, str) and s.split(" ") or s for s in s]
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pattern/text/__init__.py in find_tokens(self, string, **kwargs)
#    1103               abbreviations = kwargs.get("abbreviations", ABBREVIATIONS),
#    1104                     replace = kwargs.get("replace", replacements),
# -> 1105                   linebreak = r"\n{2,}")
#    1106
#    1107     def find_tags(self, tokens, **kwargs):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pattern/text/__init__.py in find_tokens(string, punctuation, abbreviations, replace, linebreak)
#    1410             tail = []
#    1411             if not RE_MENTION.match(t):
# -> 1412                 while t.startswith(punctuation) and \
#    1413                   t not in replace:
#    1414                     # Split leading punctuation.
#
# KeyboardInterrupt:

# %%
tops_nn['elements'][:20]
# Out:
#                      word similarity
# 0                features       0.53
# 1                 aspects      0.502
# 2               mechanics      0.477
# 3              techniques      0.472
# 4                   ideas      0.457
# 5                 поиграл      0.435
# 6                concepts      0.433
# 7                  things      0.421
# 8              influences      0.419
# 9                  วไปเเน      0.412
# 10          AJAX_toolkits      0.411
# 11         deconstruction      0.409
# 12               dynamics      0.403
# 13            intricacies        0.4
# 14           นมากเเนวเอาต      0.399
# 15  harmonic_progressions      0.399
# 16               classics      0.398
# 17                 pegada      0.396
# 18                puzzles      0.395
# 19                 themes      0.395

# %%
tops = {
    'Borderlands': None,
    'facets': None,
    'adjective': None,
    'type': None,
    'multiplayer': None,
    'characteristics': None,
    'gameplay': None,   # Good example for 3- find adjectives (or other information) characteristics of a facet of a game
    'god': None,
    'FF7': None,
    'rts': None,
}
for top in tops:
    tops[top] = my_model.model.most_similar(top, topn=1000)
    tops[top] = np.array(tops[top])[:, 0].tolist()
    tops[top] = [parse(k) for k in tops[top]]
    tops[top] = [x.split("/")[0] for x in tops[top] if x.split("/")[1] in ["JJ", "JJR", "JJS"]]

# %%
tops["gameplay"]
# Out:
# ['interesting',
#  'fabletown',
#  'audio',
#  'undepowered',
#  'suggestive',
#  'fortissimos',
#  'awesomemusic',
#  'Densely_packed',
#  'satiny',
#  'visual',
#  'textural',
#  'Schubertian',
#  'delicate_filigree',
#  'narrative',
#  'fanlike',
#  'dull',
#  'gameplay_mechanic',
#  'floral_motifs',
#  'flowerlike',
#  'varied',
#  'precise',
#  'fried_eggplant',
#  'objets_de',
#  'violenced',
#  'lace_applique_floral',
#  'enantiomeric',
#  'Service_Medal_Noncommissioned',
#  'fernlike',
#  'good',
#  'fluted_columns',
#  'digressive',
#  'Lutoslawski',
#  'inaccurate',
#  'organzas',
#  'overworld_map',
#  'flimsy',
#  'orangey_yellow',
#  'Mindquarry_Mindshare_MindTouch_Molecular',
#  'honeycomb_mesh',
#  'grated_ginger',
#  'strummed_acoustic',
#  'unispired',
#  'Lisztian',
#  'crumbled_feta_cheese',
#  'orange_zest',
#  'Hedgehog_Sonic',
#  'mashed_garlic',
#  'custardy',
#  'roasted_eggplant',
#  'Pradeep_Unni_senior',
#  'concentric_circular',
#  'Ravel_La_Valse',
#  'timbral',
#  'intricate_geometric',
#  'fontina_cheese',
#  'geometrical',
#  'fresh_basil',
#  'clunky',
#  'meticulously_sculpted',
#  'including_RPD_Recurrent',
#  'raisiny',
#  'stylised']

# %%
tops["multiplayer"]
# Out:
# ['online',
#  'iPhoneDrive',
#  'möglich',
#  'onze',
#  'sensing_controller',
#  'cooperative',
#  'LifeBook_MH',
#  'anonymising',
#  'VIERA_Cast',
#  'fullscreen',
#  'ZumoCast',
#  'MindAlign',
#  'FormoPublish',
#  'Onlive',
#  'L#D',
#  'PacketCable_compliant',
#  'i5&slash;OS_V#R',
#  'Wordscraper',
#  'neoTouch',
#  'BuzzCast',
#  'QuickTime',
#  'uniprocessor',
#  'IP_Multicast',
#  'Postgres_Plus_Advanced',
#  'Microsoft_SkyDrive',
#  'Deutsche_Bourse',
#  'Tomos_Livingstone_Western',
#  'DNS_prefetching',
#  'MSN_Virtual',
#  'v',
#  '1GB_Nvidia_GeForce',
#  'Orc_Hosted',
#  'Moveable_Type',
#  'eCosCentric',
#  'wаtch_NFL_Live',
#  'competitive',
#  'chanted_Jahvid',
#  'ausschließlich',
#  'Ruzan_Harutyunyan',
#  'oak_savannas',
#  'memcached',
#  'VIERA_CAST_enabled',
#  'Omnidrive',
#  'Windows_Live_Mesh',
#  'instant_messenger_buddy',
#  'NAT_firewall',
#  'Wii_Speak',
#  'CD-RW&slash;DVD_combo_drive',
#  '1Gbyte',
#  'Madeleine_Brindley_Western']

# %%
display_closestwords_pcascatterplot(my_model.model, "Borderlands")
display_closestwords_pcascatterplot(my_model.model, "Portals")
display_closestwords_pcascatterplot(my_model.model, "FFVII")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-660ad0de7edf> in <module>
# ----> 1 display_closestwords_pcascatterplot(my_model.model, "Borderlands")
#       2 display_closestwords_pcascatterplot(my_model.model, "Portals")
#       3 display_closestwords_pcascatterplot(my_model.model, "FFVII")
#
# NameError: name 'display_closestwords_pcascatterplot' is not defined
